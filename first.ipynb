# %%
import pandas as pd
import matplotlib.pyplot as plt
d=pd.read_csv('/content/Frogs_MFCCs.csv')

# %%
print(d)
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0          1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1          1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2          1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3          1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4          1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
# ...        ...       ...       ...       ...       ...       ...       ...
# 7190       1.0 -0.554504 -0.337717  0.035533  0.034511  0.443451  0.093889
# 7191       1.0 -0.517273 -0.370574  0.030673  0.068097  0.402890  0.096628
# 7192       1.0 -0.582557 -0.343237  0.029468  0.064179  0.385596  0.114905
# 7193       1.0 -0.519497 -0.307553 -0.004922  0.072865  0.377131  0.086866
# 7194       1.0 -0.508833 -0.324106  0.062068  0.078211  0.397188  0.094596
#
# ...

# %%
print(d.isna())
print(d.isnull())
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0        False     False     False     False     False     False     False
# 1        False     False     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ...        ...       ...       ...       ...       ...       ...       ...
# 7190     False     False     False     False     False     False     False
# 7191     False     False     False     False     False     False     False
# 7192     False     False     False     False     False     False     False
# 7193     False     False     False     False     False     False     False
# 7194     False     False     False     False     False     False     False
#
# ...

# %%
print(d[4:9])
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
# 5       1.0  0.099704 -0.033408  0.349895  0.344535  0.247569  0.022407
# 6       1.0  0.021676 -0.062075  0.318229  0.380439  0.179043 -0.041667
# 7       1.0  0.145130 -0.033660  0.284166  0.279537  0.175211  0.005791
# 8       1.0  0.271326  0.027777  0.375738  0.385432  0.272457  0.098192
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
# 5 -0.213767 -0.127916  0.277353  ... -0.080487 -0.130089 -0.171478 -0.071569
# 6 -0.252300 -0.167117  0.220027  ... -0.046620 -0.055146 -0.085972 -0.009127
# 7 -0.183329 -0.158483  0.192567  ... -0.055978 -0.048219 -0.056637 -0.022419
# 8 -0.173730 -0.157857  0.207181  ... -0.120723 -0.112607 -0.156933 -0.118527
#
# ...

# %%
x1=d['MFCCs_ 1']
y1=d['MFCCs_ 2']

# %%
plt.xlabel("MFCCS_1")
plt.ylabel("MFCCS_2")
plt.plot(x1,y1)

# %%
plt.scatter(x1,y1)

# %%
plt.xlabel("MFCCS_1")
plt.ylabel("MFCSS_2")
color = 'green'
plt.plot(x1,y1, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x2=d['MFCCs_ 3']
y2=d['MFCCs_ 4']

# %%
plt.xlabel("mfccs_3")
plt.ylabel("mfccs_4")
plt.plot(x2,y2)

# %%
plt.scatter(x3,y3)

# %%
plt.xlabel("mfccs_3")
plt.ylabel("mfccs_4")
plt.plot(x2,y2, marker = 'o', markerfacecolor = 'y')
plt.show()

# %%
x3=d['MFCCs_ 5']
y3=d['MFCCs_ 6']

# %%
plt.xlabel("mfccs_5")
plt.ylabel("mfccs_6")
plt.plot(x3,y3)

# %%
plt.scatter(x3,y3)

# %%
x4=d['MFCCs_ 7']
y4=d['MFCCs_ 8']

# %%
plt.xlabel("MFCCS_7")
plt.ylabel("MFCCS_8")
plt.plot(x4,y4)

# %%
plt.scatter(x4,y4)

# %%
plt.xlabel("MFCCS_7")
plt.ylabel("MFCSS_8")
color = 'green'
plt.plot(x4,y4, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x5=d['MFCCs_ 9']
y5=d['MFCCs_10']

# %%
plt.xlabel("MFCCS_9")
plt.ylabel("MFCCS_10")
plt.plot(x5,y5)

# %%
plt.scatter(x5,y5)

# %%
plt.xlabel("MFCCS_9")
plt.ylabel("MFCSS_10")
color = 'green'
plt.plot(x1,y1, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x6=d['MFCCs_11']
y6=d['MFCCs_12']

# %%
plt.xlabel("MFCCS_11")
plt.ylabel("MFCCS_12")
plt.plot(x6,y6)

# %%
plt.scatter(x6,y6)

# %%
plt.xlabel("MFCCS_11")
plt.ylabel("MFCSS_12")
color = 'green'
plt.plot(x6,y6, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x7=d['MFCCs_13']
y7=d['MFCCs_14']

# %%
plt.xlabel("MFCCS_13")
plt.ylabel("MFCCS_14")
plt.plot(x7,y7)

# %%
plt.scatter(x7,y7)

# %%
plt.xlabel("MFCCS_13")
plt.ylabel("MFCSS_14")
color = 'green'
plt.plot(x7,y7, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x8=d['MFCCs_15']
y8=d['MFCCs_16']

# %%
plt.xlabel("MFCCS_15")
plt.ylabel("MFCCS_16")
plt.plot(x8,y8)

# %%
plt.scatter(x8,y8)

# %%
plt.xlabel("MFCCS_15")
plt.ylabel("MFCSS_16")
color = 'green'
plt.plot(x8,y8, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x9=d['MFCCs_17']
y9=d['MFCCs_18']

# %%
plt.xlabel("MFCCS_17")
plt.ylabel("MFCCS_18")
plt.plot(x9,y9)

# %%
plt.scatter(x9,y9)

# %%
plt.xlabel("MFCCS_17")
plt.ylabel("MFCSS_18")
color = 'green'
plt.plot(x9,y9, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x10=d['MFCCs_19']
y10=d['MFCCs_20']

# %%
plt.xlabel("MFCCS_19")
plt.ylabel("MFCCS_20")
plt.plot(x10,y10)

# %%
plt.scatter(x10,y10)

# %%
plt.xlabel("MFCCS_19")
plt.ylabel("MFCSS_20")
color = 'green'
plt.plot(x10,y10, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x11=d['MFCCs_21']
y11=d['MFCCs_22']

# %%
plt.xlabel("MFCCS_21")
plt.ylabel("MFCCS_22")
plt.plot(x11,y11)

# %%
plt.scatter(x11,y11)

# %%
plt.xlabel("MFCCS_21")
plt.ylabel("MFCSS_22")
color = 'green'
plt.plot(x11,y11, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x12=d['Family']
y12=d['Genus']

# %%
plt.xlabel("family")
plt.ylabel("genius")
plt.plot(x12,y12)

# %%
plt.scatter(x12,y12)

# %%
plt.xlabel("Family")
plt.ylabel("Genius")
color = 'green'
plt.plot(x12,y12, marker = 'o', markerfacecolor = 'r')
plt.show()

# %%
x13=d['Species']
y13=d['RecordID']

# %%
plt.xlabel("species")
plt.ylabel("recordid")
plt.plot(x3,y3)
